# %%
import pandas as pd
import seaborn as sns
import matplotlib as mp
import tweepy

# %%
from tweepy import OAuthHandler
consumer_key = 'L2mPv8Oxjs2mLtBEWZZiyDy0W'
consumer_secret = 'idPHQogjNLSKdo7ns8exk9ZXSbIsqcd4UsXd1vofliwj1s2iZj'
access_token = '1413867470-bWJRTSz2Ece90tG1Z5IU9pmPZQvdWR10xrWqNBL'
access_secret = '6Z0X9eJ0dLlYJj8JrqX6VcNMOOsTWpaxaFosJhiv5Xkoa'
 
auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
 
api = tweepy.API(auth)

# %%
nomColmn = ['Username', 'Nb_Followers']
figaro = pd.read_csv('usernames_nbfollowers_figaro.csv', names=nomColmn)
figaro = figaro.dropna()
print(figaro.shape)
figaro.head()
# Out:
# (299974, 2)
#         Username  Nb_Followers
# 1        TDrevet            14
# 2    OYacine1983             0
# 3  LaguerieSarah             0
# 4    ChrisJousse             0
# 5   Puyguillaume            42

# %%
nomColmn = ['Username', 'Nb_Followers']
libe = pd.read_csv('usernames_nbfollowers_libe.csv', names=nomColmn)
libe = libe.dropna()
print(libe.shape)
libe.head()
# Out:
# (299971, 2)
#           Username  Nb_Followers
# 1       GUILAGUIJP            29
# 2   LePetitDuc_Web             1
# 3  WinchesterDea20             5
# 4       said_tarza             1
# 5  Moustap86528445             2

# %% [markdown]
# ## Affichage de la distribution par nombres de followers pour les followers du Figaro et de Libé

# %%
mp.pyplot.figure(figsize=(30,10))
sns.distplot(figaro['Nb_Followers'], axlabel='Nombre de followers')
# Out:
# f:\programmes\python\python39\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Nombre de followers', ylabel='Density'>

# %%
mp.pyplot.figure(figsize=(30,10))
sns.distplot(libe['Nb_Followers'], axlabel='Nombre de followers')
# Out:
# f:\programmes\python\python39\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Nombre de followers', ylabel='Density'>

# %% [markdown]
# ## Autres explorations de la répartition des données

# %%
libe.Nb_Followers.max()
# Out:
# 51880364

# %%
figaro.Nb_Followers.max()
# Out:
# 51880216

# %%
libe[libe.Nb_Followers >= 100].shape
# Out:
# (40001, 2)

# %%
figaro[figaro.Nb_Followers >= 100].shape
# Out:
# (35141, 2)

# %%
libe[libe.Nb_Followers > 50000000].head()
# Out:
#            Username  Nb_Followers
# 258306  jimmyfallon      51880364

# %%
figaro[figaro.Nb_Followers > 50000000].head()
# Out:
#            Username  Nb_Followers
# 298566  jimmyfallon      51880216

# %%
user = api.get_user('jimmyfallon')
print(user)
# Out:
# User(_api=<tweepy.api.API object at 0x000002022FE41F10>, _json={'id': 15485441, 'id_str': '15485441', 'name': 'jimmy fallon', 'screen_name': 'jimmyfallon', 'location': 'New York, New York', 'profile_location': None, 'description': 'astrophysicist', 'url': 'https://t.co/HFIIK3zjxo', 'entities': {'url': {'urls': [{'url': 'https://t.co/HFIIK3zjxo', 'expanded_url': 'http://5MoreSleepsTilChristmas.com', 'display_url': '5MoreSleepsTilChristmas.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 51881679, 'friends_count': 10114, 'listed_count': 63217, 'created_at': 'Fri Jul 18 19:46:50 +0000 2008', 'favourites_count': 4185, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': True, 'statuses_count': 13144, 'lang': None, 'status': {'created_at': 'Tue Nov 24 14:59:41 +0000 2020', 'id': 1331251145520582667, 'id_str': '1331251145520582667', 'text': 'News &amp; Jokes for Tuesday 11/24/20. #FallonTonight #FallonMono https://t.co/haj
# ...

# %%
figaro_sz = figaro[figaro.Nb_Followers > 10000]
libe_sz = libe[libe.Nb_Followers > 10000]
print(figaro_sz.shape)
print(libe_sz.shape)
# Out:
# (505, 2)
# (557, 2)

# %%
mp.pyplot.figure(figsize=(30,10))
sns.distplot(figaro_sz['Nb_Followers'], axlabel='Nombre de followers')
# Out:
# f:\programmes\python\python39\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Nombre de followers', ylabel='Density'>

# %%
mp.pyplot.figure(figsize=(30,10))
sns.distplot(libe_sz['Nb_Followers'], axlabel='Nombre de followers')
# Out:
# f:\programmes\python\python39\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Nombre de followers', ylabel='Density'>
